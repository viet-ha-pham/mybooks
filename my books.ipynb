# %%
import pandas as pd
df = pd.read_excel('mybooks.xlsx')
df
# Out:
#                               Tên sách Loại sách              Nhóm sách  \
# 0                   Bộ truyện Doraemon        Ly  Sách thanh thiếu niên
# 1    Bộ truyện Thám Tử Lừng Danh Conan        Ly  Sách thanh thiếu niên
# 2                  Bộ truyện Kindaichi        Ly  Sách thanh thiếu niên
# 3                     Bộ truyện Naruto        Ly  Sách thanh thiếu niên
# 4        Bộ truyện Chú Thuật Hồi Chiến        Ly  Sách thanh thiếu niên
# ..                                 ...       ...                    ...
# 508              Án mạng trên sân golf        Ly                Văn học
# 509                  Chuỗi án mạng ABC        Ly                Văn học
# 510                   Ngôi nhà quái dị        Ly                Văn học
# 511                   Vọng lâu tử thần        Ly                Văn học
# 512                   Bí ẩn ba phần tư        Ly                Văn học
#
#               Phân nhóm         Thẻ Vị trí Ghi chú
# 0                 Manga       robot  Ở nhà     NaN
# ...

# %%
import random
random_book=random.choice(list(df.loc[(df['Vị trí'] =="Ở nhà") & (df['Loại sách'] !="Ly"),"Tên sách"]))
random_book
# Out:
# 'Đời sống mới'
